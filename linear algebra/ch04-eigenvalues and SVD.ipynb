# %% [markdown]
# #### 코드 참조
# [1] https://github.com/rickiepark/machine-learning-with-python-cookbook
# [2] https://docs.scipy.org/doc/scipy/reference/tutorial/linalg.html
# [3] https://github.com/mikexcohen/LinAlgBook/blob/main/python
# [4] https://docs.sympy.org/latest/tutorial/matrices.html
# [5] Dr. Jaewook Lee's Lecture Notes

# %% [markdown]
# # 4장 고유치와 SVD (Eigenvalues and SVD)

# %% [markdown]
# ## 4.1. Eigenvalues and eigenvectors

# %%
import numpy as np
from scipy.linalg import eig,hankel
import matplotlib.pyplot as plt

# %%
A = np.array([[1, 5, 2], [2, 4, 1], [3, 6, 2]])
L, V = np.linalg.eig(A)
L = np.diag(L)
print(L)
print(V)
# Out:
# [[ 7.9579162   0.          0.        ]
#  [ 0.         -1.25766471  0.        ]
#  [ 0.          0.          0.2997485 ]]
# [[-0.5297175  -0.90730751  0.28380519]
#  [-0.44941741  0.28662547 -0.39012063]
#  [-0.71932146  0.30763439  0.87593408]]

# %%
print(np.sum(abs(V**2), axis=0))  # eigenvectors are unitary
# Out:
# [1. 1. 1.]

# %%
print(np.linalg.norm(A@V[:,0] - L[0,0]*V[:,0]))  # check the computation
# Out:
# 3.233018248352212e-15

# %%
# create two random matrices
n = 4
A = np.random.randn(n,n)
B = np.random.randn(n,n)
# note that this is scipy's eig, not numpy's
evals,evecs = eig(A,B)  # Ax=rBx generalized eigenvalues
print(evals)
print(evecs)
# Out:
# [3.30335582+0.j         0.24796467+0.66941004j 0.24796467-0.66941004j
#  0.08028085+0.j        ]
# [[ 0.45586523+0.j          0.75753691-0.11497357j  0.75753691+0.11497357j
#    0.20117369+0.j        ]
#  [-0.71538463+0.j          0.0597796 -0.00647647j  0.0597796 +0.00647647j
#   -0.31589747+0.j        ]
#  [ 0.38787168+0.j          0.26129775+0.35133341j  0.26129775-0.35133341j
#   -0.48878866+0.j        ]
#  [ 0.36050975+0.j          0.05792276-0.46285705j  0.05792276+0.46285705j
#   -0.78792359+0.j        ]]

# %%
l1 = eig(A,B)[0]
l2 = eig(np.linalg.inv(B)@A)[0]
print(l1)
print(l2)
# Out:
# [3.30335582+0.j         0.24796467+0.66941004j 0.24796467-0.66941004j
#  0.08028085+0.j        ]
# [3.30335582+0.j         0.24796467+0.66941004j 0.24796467-0.66941004j
#  0.08028085+0.j        ]

# %%
# initialize results vector
avediffs = np.zeros(100)

# loop over matrix sizes
for n in range(1,101):
    
    # create matrices
    A = np.random.randn(n,n)
    B = np.random.randn(n,n)
    
    # GED
    l1 = eig(A,B)[0]
    l2 = eig(np.linalg.inv(B)@A)[0]

    # important to sort eigvals
    l1.sort()
    l2.sort()
    
    # their differences
    avediffs[n-1] = np.mean(np.abs(l1-l2))
    
    
# visualize
plt.plot(avediffs)
plt.show()

# %%
# create the hankel matrix
t = np.arange(1,51)
lstrow = np.append(t[-1],np.arange(1,t[-1]))
H = hankel(t,r=lstrow)

# eigendecomposition
d,V = np.linalg.eig(H)
V = V[:,np.argsort(d)[::-1]]


# the matrix
plt.subplot(221) 
plt.imshow(H)

# the eigenvectors
plt.subplot(222) 
plt.imshow(V)

# some evecs
plt.subplot(212) 
plt.plot(V[:,:4])

plt.show()

# %% [markdown]
# ## 4.2. SVD

# %%
import numpy as np
from scipy import linalg
A = np.array([[1,2,3],[-1,5,6],[2,3,1],[3,-2,2]])
A
# Out:
# array([[ 1,  2,  3],
#        [-1,  5,  6],
#        [ 2,  3,  1],
#        [ 3, -2,  2]])

# %%
m,n = A.shape
U,s,Vt = linalg.svd(A)
Sig = linalg.diagsvd(s,m,n)
U.shape,  s.shape, Vt.shape
# Out:
# ((4, 4), (3,), (3, 3))

# %%
print(U)
print(Sig)
print(Vt)
# Out:
# [[-0.39889953 -0.23698421 -0.0405507  -0.88491428]
#  [-0.86268939  0.19596266  0.33821136  0.32090298]
#  [-0.30968347 -0.15808665 -0.91053892  0.22365965]
#  [-0.02724569 -0.9383207   0.23428101  0.25283265]]
# [[9.01518058 0.         0.        ]
#  [0.         4.33688954 0.        ]
#  [0.         0.         2.63019166]
#  [0.         0.         0.        ]]
# [[-0.02632384 -0.66396951 -0.74729616]
#  [-0.8218061   0.43999883 -0.36198864]
#  [-0.56915885 -0.60460361  0.55723665]]

# %%
linalg.norm(Vt,axis=1)  # 행벡터 norm
# Out:
# array([1., 1., 1.])

# %%
U@Sig@Vt #check computation
# Out:
# array([[ 1.,  2.,  3.],
#        [-1.,  5.,  6.],
#        [ 2.,  3.,  1.],
#        [ 3., -2.,  2.]])

# %%
U_r,s_r,Vt_r = linalg.svd(A,full_matrices=False)  # Reduced SVD
print(U_r)
print(np.diag(s_r))
print(Vt_r)
# Out:
# [[-0.39889953 -0.23698421 -0.0405507 ]
#  [-0.86268939  0.19596266  0.33821136]
#  [-0.30968347 -0.15808665 -0.91053892]
#  [-0.02724569 -0.9383207   0.23428101]]
# [[9.01518058 0.         0.        ]
#  [0.         4.33688954 0.        ]
#  [0.         0.         2.63019166]]
# [[-0.02632384 -0.66396951 -0.74729616]
#  [-0.8218061   0.43999883 -0.36198864]
#  [-0.56915885 -0.60460361  0.55723665]]

# %%
# matrix
A = np.random.randn(4,5)

# get V
L2,V = np.linalg.eig(A.T@A) 
# sort by descending eigenvalues
V = V[:,np.argsort(L2)[::-1]]

# get U
L2,U = np.linalg.eig(A@A.T) 
# sort by descending eigenvalues
U = U[:,np.argsort(L2)[::-1]]

# create Sigma
S = np.zeros(A.shape)
for i,s in enumerate(np.sort(L2)[::-1]):
    S[i,i] = np.sqrt(s)

# now get the SVD    
U2,S2,V2 = np.linalg.svd(A)
print(U)
print(U2)
print(np.diag(S),np.diag(S2))
print(V)
print(V2)
# Out:
# [[-0.4480431  -0.53181096  0.31317951  0.64680219]
#  [-0.85065075  0.36166576  0.13457612 -0.35704404]
#  [-0.13159494  0.51421037 -0.58384081  0.61432921]
#  [ 0.24152319  0.56741755  0.73684311  0.27706695]]
# [[ 0.4480431   0.53181096 -0.31317951 -0.64680219]
#  [ 0.85065075 -0.36166576 -0.13457612  0.35704404]
#  [ 0.13159494 -0.51421037  0.58384081 -0.61432921]
#  [-0.24152319 -0.56741755 -0.73684311 -0.27706695]]
# [2.83767112 2.36763317 1.62478326 0.72786002] [[2.83767112 0.         0.         0.        ]
#  [0.         2.36763317 0.         0.        ]
#  [0.         0.         1.62478326 0.        ]
#  [0.         0.         0.         0.72786002]]
# [[-0.4174559   0.22323711  0.74058827  0.37424579  0.29557548]
#  [-0.01602978 -0.05809316 -0.23355667  0.84951635 -0.46919238]
#  [ 0.49930316  0.61005139  0.35384044 -0.12136361 -0.4884685 ]
#  [-0.08527062  0.73150279 -0.50889284  0.14187118  0.42253193]
#  [-0.75425386  0.19882492 -0.1131606  -0.32156726 -0.52474654]]
# [[-0.4174559  -0.01602978  0.49930316 -0.08527062 -0.75425386]
#  [ 0.22323711 -0.05809316  0.61005139  0.73150279  0.19882492]
#  [ 0.74058827 -0.23355667  0.35384044 -0.50889284 -0.1131606 ]
#  [ 0.37424579  0.84951635 -0.12136361  0.14187118 -0.32156726]
#  [-0.29557548  0.46919238  0.4884685  -0.42253193  0.52474654]]

# %%
# a matrix
A = np.random.randn(5,5)

# its singular values
s = linalg.svd(A)[1]

# "manual" condition number
condnum = np.max(s)/np.min(s)

# compare above with numpy's cond()
print(condnum,np.linalg.cond(A))
# Out:
# 20.054801642756637 20.054801642756633

# %% [markdown]
# ## 4.3. SVD application

# %%
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from scipy.linalg import eig
# setup the figure
fig,ax = plt.subplots(2,4)

# create the matrix and get its SVD
A = np.random.randn(5,3)
U,s,V = np.linalg.svd(A)
S = np.diag(s) # need Sigma as matrix

# loop over layers
for i in range(3):
    
    # compute and show one layer
    onelayer = np.outer(U[:,i],V[i,:])*s[i]
    ax[0,i].imshow(onelayer)
    ax[0,i].set_title('Layer %g'%i)
    ax[0,i].axis('off')
    
    # compute the low-rank approximation up to this layer
    lowrank = U[:,:i+1]@S[:i+1,:i+1]@V[:i+1,:]
    ax[1,i].imshow(lowrank)
    ax[1,i].set_title('Layers 0:%g'%i)
    ax[1,i].axis('off')
    

# finally, show the original matrix
ax[1,3].imshow(A)
ax[1,3].set_title('Orig. A')
ax[1,3].axis('off')
ax[0,3].axis('off')
plt.show()

# %%
# matrix sizes
m = 6
n = 16

# desired condition number
condnum = 42

# create U and V from random numbers
U,r = np.linalg.qr( np.random.randn(m,m) )
V,r = np.linalg.qr( np.random.randn(n,n) )

# create singular values vector
s = np.linspace(condnum,1,np.min((m,n)))
S = np.zeros((m,n))
for i in range(min((m,n))):
    S[i,i] = s[i]

# construct matrix
A = U@S@V.T 

# confirm!
np.linalg.cond(A)
# Out:
# 41.99999999999995

# %%
# download picture and convert to float
pic = imread('https://upload.wikimedia.org/wikipedia/en/8/86/Einstein_tongue.jpg')
np.array(pic,dtype=float)

# SVD and create sigma matrix
U,s,V = np.linalg.svd( pic )
S = np.zeros(pic.shape)
for i in range(len(s)):
    S[i,i] = s[i]

# number of components to use
comps = slice(0,21) 

# create the low-rank approx.
lowrank = U[:,comps]@S[comps,comps]@V[comps,:]


# show the original and low-rank
plt.subplot(1,2,1)
plt.imshow(pic,cmap='gray')
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(lowrank,cmap='gray')
plt.title('Comps. %g-%g'%(comps.start,comps.stop-1));

# %%
# convert to percent explained
s = 100*s/np.sum(s)

# visualize
plt.plot(s,'s-')
plt.xlim([0,100])
plt.xlabel('Component number')
plt.ylabel('Pct variance explains')
plt.show()


# threshold in percent
thresh = 4 
I,J=np.ix_(s>thresh,s>thresh) # comps > X%
lowrank = np.squeeze(U[:,J]@S[I,J]@V[J,:])


# show the original and low-rank
plt.subplot(1,2,1)
plt.imshow(pic,cmap='gray')
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(lowrank,cmap='gray')
plt.title('%g comps. at %g%%'%(len(I),thresh));

# %%
# initialize RMS vector
RMS = np.zeros(len(s))

# loop through singular values (SVD layers)
for si in range(len(s)):
    
    # create the low-rank img
    i = si+1 # mind the indexing!
    lowrank = U[:,:i]@S[:i,:i]@V[:i,:]
    
    # get the difference
    diffimg = lowrank - pic
    
    # compute RMS for this rank
    RMS[si] = np.sqrt(np.mean(diffimg.flatten()**2))

    
# how's it look?!?
plt.plot(RMS,'s-')
plt.xlabel('Rank approximation')
plt.ylabel('Error (a.u.)')
plt.show()

# %% [markdown]
# ### Moore-Penrose pseudo-inverse

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
# some random tall matrix  with m>n
M = np.random.randint(low=1,high=7,size=(5,2))
print(M)
U,s,V = np.linalg.svd(M) 
m,n=M.shape
S=linalg.diagsvd(s,m,n)
Spinv=linalg.diagsvd(1/s,m,n)

Mpinv1 = np.linalg.inv( V.T@V ) @ (U@Spinv@V).T
print(Mpinv1)
# 유사 역행렬 pinv을 계산합니다.
Mpinv = np.linalg.pinv(M)
print(Mpinv)
Mpinv1 - Mpinv
# Out:
# [[6 3]
#  [6 1]
#  [6 6]
#  [5 3]
#  [2 1]]
# [[ 0.06024096  0.14859438 -0.07228916  0.02811245  0.02008032]
#  [-0.0292599  -0.18646013  0.20654045  0.01491681 -0.0097533 ]]
# [[ 0.06024096  0.14859438 -0.07228916  0.02811245  0.02008032]
#  [-0.0292599  -0.18646013  0.20654045  0.01491681 -0.0097533 ]]
# array([[-1.38777878e-17, -2.77555756e-17,  1.38777878e-17,
#         -6.93889390e-18, -3.46944695e-18],
#        [ 6.93889390e-18,  2.77555756e-17, -5.55111512e-17,
#         -3.46944695e-18,  1.73472348e-18]])

# %%
np.allclose(M, np.dot(M, np.dot(Mpinv, M)))
# Out:
# True

# %%
np.allclose(Mpinv, np.dot(Mpinv, np.dot(M, Mpinv)))
# Out:
# True

# %%
# matrix size
M = 10 

# condition numbers
cns = np.linspace(10,1e10,30)

# results vector
avediffs = np.zeros(len(cns))

# loop over condition numbers
for condi in range(len(cns)):
    
    # create A
    U,r = np.linalg.qr( np.random.randn(M,M) )
    V,r = np.linalg.qr( np.random.randn(M,M) )
    S = np.diag(np.linspace(cns[condi],1,M))
    A = U@S@V.T # construct matrix  
  
    # create B
    U,r = np.linalg.qr( np.random.randn(M,M) )
    V,r = np.linalg.qr( np.random.randn(M,M) )
    S = np.diag(np.linspace(cns[condi],1,M))
    B = U@S@V.T # construct matrix
  
    # GEDs and sort
    l1 = eig(A,B)[0]
    l2 = eig(np.linalg.inv(B)@A)[0]
    l1.sort()
    l2.sort()
  
    # get differences
    avediffs[condi] = np.mean(np.abs(l1-l2))

# plot them!
plt.plot(cns,avediffs)
plt.show()
